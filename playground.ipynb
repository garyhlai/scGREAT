# %%
import numpy as np
import pandas as pd
import time
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.optim.lr_scheduler import StepLR
from torch.utils.data import DataLoader
from sklearn.preprocessing import StandardScaler
from dataset import Dataset
from model import scGREAT
from train_val import train,validate


data_dir = 'hESC500'
# data_dir = 'mESC500'
expression_data_path = data_dir + '/BL--ExpressionData.csv'
biovect_e_path       = data_dir + '/biovect768.npy'
train_data_path      = data_dir + '/Train_set.csv'
val_data_path        = data_dir + '/Validation_set.csv'
test_data_path       = data_dir + '/Test_set.csv'
expression_data = np.array(pd.read_csv(expression_data_path,index_col=0,header=0))

# Data Preprocessing
standard = StandardScaler()
scaled_df = standard.fit_transform(expression_data.T)
expression_data = scaled_df.T
expression_data_shape = expression_data.shape 

train_dataset = Dataset(train_data_path, expression_data)
val_dataset = Dataset(val_data_path, expression_data)
test_dataset = Dataset(test_data_path, expression_data)

# %%
# SANITY ORIGINAL MODEL
train_loader = torch.utils.data.DataLoader(dataset=train_dataset,
                                               batch_size=32,
                                               shuffle=True,
                                               drop_last=False,
                                               num_workers=0)
print(f"train_loader has {len(train_loader)} batches")

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
for idx, (gene_pair_index, expr_embedding, label) in enumerate(train_loader):
        label = label.to(device)
        gene_pair_index = gene_pair_index.to(device)
        expr_embedding = expr_embedding.to(torch.float32)
        expr_embedding = expr_embedding.to(device)
        break

print(gene_pair_index.shape, expr_embedding.shape, label.shape)

T = scGREAT(expression_data_shape,768,2,4,biovect_e_path)
predicted_label = T(gene_pair_index, expr_embedding)
print(predicted_label.shape, predicted_label)
# Out:
# train_loader has 647 batches
# torch.Size([32, 2]) torch.Size([32, 2, 758]) torch.Size([32])
# torch.Size([32, 1]) tensor([[0.4856],
#         [0.5310],
#         [0.5134],
#         [0.5054],
#         [0.5034],
#         [0.5394],
#         [0.5406],
#         [0.5385],
#         [0.4284],
#         [0.4570],
#         [0.4467],
#         [0.5221],
#         [0.4799],
#         [0.4964],
#         [0.5045],
#         [0.5748],
#         [0.5023],
#         [0.5693],
#         [0.5390],
#         [0.4825],
#         [0.5336],
#         [0.5211],
#         [0.5392],
#         [0.5054],
#         [0.5352],
#         [0.5461],
#         [0.5105],
#         [0.4701],
#         [0.4989],
#         [0.5508],
#         [0.5140],
#         [0.5477]], grad_fn=<SigmoidBackward0>)

# %%
import torch
import numpy as np
import pandas as pd

class GeneInteractionDataset(torch.utils.data.Dataset):
    def __init__(self, data_path, expression_data):
        # Load labeled gene pairs
        data = pd.read_csv(data_path, index_col=0, header=0)

        self.labeled_pairs = data[['TF', 'Target']].values
        self.labels = torch.tensor(data['Label'].values.astype(np.float32))  # Convert labels to float32
        self.expression_data = torch.tensor(expression_data, dtype=torch.float32)  # [num_genes, embedding_dim]
        self.num_genes = self.expression_data.shape[0]

    def __len__(self):
        return 1  # Since the expression data is the same, we can return a single sample

    def __getitem__(self, idx):
        # Gene embeddings
        expr_embedding = self.expression_data  # [num_genes, embedding_dim]

        # Initialize label matrix (all -1) and mask (all 0)
        label_matrix = -torch.ones((self.num_genes, self.num_genes), dtype=torch.float32)  
        mask = torch.zeros((self.num_genes, self.num_genes), dtype=torch.float32)

        # Fill in the labels and mask for labeled pairs
        for (i, j), label in zip(self.labeled_pairs, self.labels):
            label_matrix[i, j] = label  # Assign the label (1 or 0)
            mask[i, j] = 1.0            # Mark as labeled

        return expr_embedding, label_matrix, mask

# %%
interaction_train_ds = GeneInteractionDataset(train_data_path, expression_data)
interaction_val_ds = GeneInteractionDataset(val_data_path, expression_data)
interaction_test_ds = GeneInteractionDataset(test_data_path, expression_data)

interaction_train_loader = torch.utils.data.DataLoader(
    dataset=interaction_train_ds,
    batch_size=1,
    shuffle=True,
    num_workers=0
)
interaction_val_loader = torch.utils.data.DataLoader(
    dataset=interaction_val_ds,
    batch_size=1,
    shuffle=False,
    num_workers=0
)
interaction_test_loader = torch.utils.data.DataLoader(
    dataset=interaction_test_ds,
    batch_size=1,
    shuffle=False,
    num_workers=0
)

# %%
import sys
sys.path.append('/Users/factored/Dev/GEARS/gears')
from gene_transformer import *
class GrnTransformer(nn.Module):
    """Input is a tensor of shape (batch_size, num_genes, embed_dim) and output is a tensor of shape (batch_size, num_genes)."""

    def __init__(
        self,
        num_genes, # Different from GeneExpressionTransformer from GEARS
        embed_dim=64,
        num_heads=8,
        hidden_dim=256,
        num_layers=1,
        group_size=512,
        dropout=0.0,
    ):
        super().__init__()
        self.layers = nn.ModuleList(
            [
                TransformerLayer(embed_dim, num_heads, hidden_dim, group_size, dropout)
                for _ in range(num_layers)
            ]
        )
        self.norm = RMSNorm(embed_dim)
        
        # Components different from GeneExpressionTransformer from GEARS
        # embed input vectors of size 758 to size 768. TODO: 758 is hardcoded here
        self.proj = nn.Linear(758, embed_dim)
        self.grn_pred_head = nn.Linear(hidden_dim, num_genes)


    def forward(self, x):
        x = self.proj(x)
        for layer in self.layers:
            x = layer(x)
        x = self.norm(x)
        return self.grn_pred_head(x)

# %%
# SANITY CHECK NEW MODEL
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
for expr_embedding, label_matrix, mask in interaction_train_loader:
    expr_embedding = expr_embedding.to(device)  # [batch_size, num_genes_per_sample, embedding_dim]
    label_matrix = label_matrix.to(device)      # [batch_size, num_genes_per_sample, num_genes_per_sample]
    mask = mask.to(device)     
    break

print(len(interaction_train_ds), len(interaction_train_loader))
print(expr_embedding.shape, label_matrix.shape, mask.shape)

model = GrnTransformer(
    num_genes=interaction_train_ds.expression_data.shape[0],
    embed_dim=768,
    num_heads=4,
    hidden_dim=768,
    num_layers=2,
    group_size=512,
    dropout=0.0,
)
predicted_label = model(expr_embedding) 
print(expr_embedding.shape, predicted_label.shape)
# Out:
# 1 1
# torch.Size([1, 910, 758]) torch.Size([1, 910, 910]) torch.Size([1, 910, 910])
# torch.Size([1, 910, 758]) torch.Size([1, 910, 910])

# %%
# NEW MODEL TRAINING LOOP
from sklearn.metrics import roc_auc_score, average_precision_score

def Evaluation(y_pred, y_true, mask):
    # Detach tensors and move to CPU
    y_pred = y_pred.detach().cpu()
    y_true = y_true.detach().cpu()
    mask = mask.detach().cpu()

    # Flatten the tensors
    y_pred = y_pred.view(-1)
    y_true = y_true.view(-1)
    mask = mask.view(-1)

    # Apply mask to select labeled pairs
    y_pred = y_pred[mask > 0]
    y_true = y_true[mask > 0]

    # Convert to numpy arrays
    y_pred = y_pred.numpy()
    y_true = y_true.numpy()

    try:
        # Compute evaluation metrics
        AUROC = roc_auc_score(y_true=y_true, y_score=y_pred)
        AUPRC = average_precision_score(y_true=y_true, y_score=y_pred)
    except Exception as e:
        AUROC = 0
        AUPRC = 0

    return AUROC, AUPRC

def train(model, dataloader, loss_func, optimizer, epoch, scheduler, args):
    model.train()
    log_interval = 200
    total_loss = 0

    for idx, (expr_embedding, label_matrix, mask) in enumerate(dataloader):
        # Move tensors to the appropriate device
        expr_embedding = expr_embedding.to(torch.float32).to(device)  # [batch_size, num_genes, embedding_dim]
        label_matrix = label_matrix.to(torch.float32).to(device)      # [batch_size, num_genes, num_genes]
        mask = mask.to(torch.float32).to(device)                      # [batch_size, num_genes, num_genes]

        optimizer.zero_grad()

        # Forward pass through the model
        predicted_output = model(expr_embedding)  # Should output [batch_size, num_genes, num_genes]

        # Compute the element-wise loss
        loss = loss_func(predicted_output, label_matrix)

        # Apply the mask to ignore unlabeled gene pairs
        masked_loss = loss * mask

        # Compute the mean loss over labeled pairs
        final_loss = masked_loss.sum() / mask.sum()
        total_loss += final_loss.item()

        # Backpropagation
        final_loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 0.1)
        optimizer.step()

        if args and args.scheduler_flag:
            scheduler.step()

        # Logging and evaluation
        if idx % log_interval == 0:
            AUROC, AUPRC = Evaluation(y_pred=predicted_output, y_true=label_matrix, mask=mask)
            print(
                "| epoch {:3d} | {:5d} /{:5d} batches |Train loss {:8.3f} | AUROC {:8.3f} | AUPRC {:8.3f}".format(
                    epoch, idx, len(dataloader), final_loss.item(), AUROC, AUPRC
                )
            )

    print("| epoch {:3d} | total_loss {:8.3f}".format(epoch, total_loss))


# for epoch in range(50):
#     train(model, interaction_train_loader, loss_fn, optimizer, epoch, None, None)
#     AUC_val,AUPR_val = validate(T,val_loader,loss_func)
#     print('-' * 100)
#     print('| end of epoch {:3d} |valid AUROC {:8.3f} | valid AUPRC {:8.3f}'.format(epoch,AUC_val,AUPR_val))
#     print('-' * 100)

def validate(model, dataloader, loss_func):
    model.eval()
    total_loss = 0
    pre_list = []
    lb_list = []
    mask_list = []

    with torch.no_grad():
        for idx, (expr_embedding, label_matrix, mask) in enumerate(dataloader):
            expr_embedding = expr_embedding.to(torch.float32).to(device)  # [batch_size, num_genes, embedding_dim]
            label_matrix = label_matrix.to(torch.float32).to(device)      # [batch_size, num_genes, num_genes]
            mask = mask.to(torch.float32).to(device)                      # [batch_size, num_genes, num_genes]

            # Forward pass
            predicted_output = model(expr_embedding)  # Should output [batch_size, num_genes, num_genes]

            # Compute loss (optional)
            loss = loss_func(predicted_output, label_matrix)
            masked_loss = loss * mask
            final_loss = masked_loss.sum() / mask.sum()
            total_loss += final_loss.item()

            # Collect predictions and labels
            pre_list.append(predicted_output.detach().cpu())
            lb_list.append(label_matrix.detach().cpu())
            mask_list.append(mask.detach().cpu())

        # Concatenate all batches
        y_pred = torch.cat(pre_list, dim=0)  # [total_samples, num_genes, num_genes]
        y_true = torch.cat(lb_list, dim=0)
        mask = torch.cat(mask_list, dim=0)

        # Flatten tensors
        y_pred = y_pred.view(-1)
        y_true = y_true.view(-1)
        mask = mask.view(-1)

        # Apply mask to select labeled pairs
        y_pred = y_pred[mask > 0]
        y_true = y_true[mask > 0]

        # Convert to numpy arrays
        y_pred = y_pred.numpy()
        y_true = y_true.numpy()

        try:
            # Compute evaluation metrics
            AUROC = roc_auc_score(y_true=y_true, y_score=y_pred)
            AUPRC = average_precision_score(y_true=y_true, y_score=y_pred)
        except Exception as e:
            AUROC = 0
            AUPRC = 0

    return AUROC, AUPRC


EPOCHS = 647 # The same number of steps as 1 epoch in the original model
optimizer = torch.optim.Adam(model.parameters(), lr=1e-5)
loss_fn = torch.nn.BCEWithLogitsLoss(reduction='none')

for epoch in range(1, EPOCHS + 1):
    train(model, interaction_train_loader, loss_fn, optimizer, epoch, None, None)
    AUC_val, AUPR_val = validate(model, interaction_val_loader, loss_fn)
    print('-' * 100)
    print('| end of epoch {:3d} | valid AUROC {:8.3f} | valid AUPRC {:8.3f}'.format(epoch, AUC_val, AUPR_val))
    print('-' * 100)
    AUC_test, AUPR_test = validate(model, interaction_test_loader, loss_fn)
    print('| end of epoch {:3d} | test  AUROC {:8.3f} | test  AUPRC {:8.3f}'.format(epoch, AUC_test, AUPR_test))
    print('-' * 100)

    if AUC_val < 0.501:
        print("AUC_val < 0.501 !!")
        break
# Out:
# | epoch   1 |     0 /    1 batches |Train loss    0.738 | AUROC    0.492 | AUPRC    0.144
# | epoch   1 | total_loss    0.738
# ----------------------------------------------------------------------------------------------------
# | end of epoch   1 | valid AUROC    0.530 | valid AUPRC    0.155
# ----------------------------------------------------------------------------------------------------
# | end of epoch   1 | test  AUROC    0.500 | test  AUPRC    0.147
# ----------------------------------------------------------------------------------------------------
# | epoch   2 |     0 /    1 batches |Train loss    0.736 | AUROC    0.495 | AUPRC    0.145
# | epoch   2 | total_loss    0.736
# ----------------------------------------------------------------------------------------------------
# | end of epoch   2 | valid AUROC    0.530 | valid AUPRC    0.155
# ----------------------------------------------------------------------------------------------------
# | end of epoch   2 | test  AUROC    0.500 | test  AUPRC    0.147
# ----------------------------------------------------------------------------------------------------
# | epoch   3 |     0 /    1 batches |Train loss    0.733 | AUROC    0.499 | AUPRC    0.147
# | epoch   3 | total_loss    0.733
# ----------------------------------------------------------------------------------------------------
# | end of epoch   3 | valid AUROC    0.530 | valid AUPRC    0.155
# ----------------------------------------------------------------------------------------------------
# | end of epoch   3 | test  AUROC    0.500 | test  AUPRC    0.147
# ----------------------------------------------------------------------------------------------------
# | epoch   4 |     0 /    1 batches |Train loss    0.731 | AUROC    0.502 | AUPRC    0.148
# | epoch   4 | total_loss    0.731
# ----------------------------------------------------------------------------------------------------
# | end of epoch   4 | valid AUROC    0.531 | valid AUPRC    0.155
# ----------------------------------------------------------------------------------------------------
# | end of epoch   4 | test  AUROC    0.501 | test  AUPRC    0.147
# ----------------------------------------------------------------------------------------------------
# | epoch   5 |     0 /    1 batches |Train loss    0.729 | AUROC    0.505 | AUPRC    0.149
# | epoch   5 | total_loss    0.729
# ----------------------------------------------------------------------------------------------------
# | end of epoch   5 | valid AUROC    0.531 | valid AUPRC    0.155
# ----------------------------------------------------------------------------------------------------
# | end of epoch   5 | test  AUROC    0.501 | test  AUPRC    0.147
# ----------------------------------------------------------------------------------------------------
# | epoch   6 |     0 /    1 batches |Train loss    0.727 | AUROC    0.509 | AUPRC    0.151
# | epoch   6 | total_loss    0.727
# ----------------------------------------------------------------------------------------------------
# | end of epoch   6 | valid AUROC    0.531 | valid AUPRC    0.155
# ----------------------------------------------------------------------------------------------------
# | end of epoch   6 | test  AUROC    0.501 | test  AUPRC    0.147
# ----------------------------------------------------------------------------------------------------
# | epoch   7 |     0 /    1 batches |Train loss    0.725 | AUROC    0.512 | AUPRC    0.152
# | epoch   7 | total_loss    0.725
# ----------------------------------------------------------------------------------------------------
# | end of epoch   7 | valid AUROC    0.531 | valid AUPRC    0.155
# ----------------------------------------------------------------------------------------------------
# | end of epoch   7 | test  AUROC    0.501 | test  AUPRC    0.147
# ----------------------------------------------------------------------------------------------------
# | epoch   8 |     0 /    1 batches |Train loss    0.723 | AUROC    0.516 | AUPRC    0.154
# | epoch   8 | total_loss    0.723
# ----------------------------------------------------------------------------------------------------
# | end of epoch   8 | valid AUROC    0.532 | valid AUPRC    0.155
# ----------------------------------------------------------------------------------------------------
# | end of epoch   8 | test  AUROC    0.501 | test  AUPRC    0.147
# ----------------------------------------------------------------------------------------------------
# | epoch   9 |     0 /    1 batches |Train loss    0.721 | AUROC    0.519 | AUPRC    0.155
# | epoch   9 | total_loss    0.721
# ----------------------------------------------------------------------------------------------------
# | end of epoch   9 | valid AUROC    0.532 | valid AUPRC    0.155
# ----------------------------------------------------------------------------------------------------
# | end of epoch   9 | test  AUROC    0.501 | test  AUPRC    0.147
# ----------------------------------------------------------------------------------------------------
# | epoch  10 |     0 /    1 batches |Train loss    0.719 | AUROC    0.522 | AUPRC    0.156
# | epoch  10 | total_loss    0.719
# ----------------------------------------------------------------------------------------------------
# | end of epoch  10 | valid AUROC    0.532 | valid AUPRC    0.156
# ----------------------------------------------------------------------------------------------------
# | end of epoch  10 | test  AUROC    0.502 | test  AUPRC    0.147
# ----------------------------------------------------------------------------------------------------
# | epoch  11 |     0 /    1 batches |Train loss    0.717 | AUROC    0.526 | AUPRC    0.158
# | epoch  11 | total_loss    0.717
# ----------------------------------------------------------------------------------------------------
# | end of epoch  11 | valid AUROC    0.532 | valid AUPRC    0.156
# ----------------------------------------------------------------------------------------------------
# | end of epoch  11 | test  AUROC    0.502 | test  AUPRC    0.147
# ----------------------------------------------------------------------------------------------------
# | epoch  12 |     0 /    1 batches |Train loss    0.715 | AUROC    0.529 | AUPRC    0.160
# | epoch  12 | total_loss    0.715
# ----------------------------------------------------------------------------------------------------
# | end of epoch  12 | valid AUROC    0.533 | valid AUPRC    0.156
# ----------------------------------------------------------------------------------------------------
# | end of epoch  12 | test  AUROC    0.502 | test  AUPRC    0.147
# ----------------------------------------------------------------------------------------------------
# | epoch  13 |     0 /    1 batches |Train loss    0.712 | AUROC    0.533 | AUPRC    0.161
# | epoch  13 | total_loss    0.712
# ----------------------------------------------------------------------------------------------------
# | end of epoch  13 | valid AUROC    0.533 | valid AUPRC    0.156
# ----------------------------------------------------------------------------------------------------
# | end of epoch  13 | test  AUROC    0.502 | test  AUPRC    0.147
# ----------------------------------------------------------------------------------------------------
# | epoch  14 |     0 /    1 batches |Train loss    0.710 | AUROC    0.536 | AUPRC    0.163
# | epoch  14 | total_loss    0.710
# ----------------------------------------------------------------------------------------------------
# | end of epoch  14 | valid AUROC    0.533 | valid AUPRC    0.156
# ----------------------------------------------------------------------------------------------------
# | end of epoch  14 | test  AUROC    0.502 | test  AUPRC    0.147
# ----------------------------------------------------------------------------------------------------
# | epoch  15 |     0 /    1 batches |Train loss    0.708 | AUROC    0.540 | AUPRC    0.165
# | epoch  15 | total_loss    0.708
# ----------------------------------------------------------------------------------------------------
# | end of epoch  15 | valid AUROC    0.533 | valid AUPRC    0.156
# ----------------------------------------------------------------------------------------------------
# | end of epoch  15 | test  AUROC    0.502 | test  AUPRC    0.148
# ----------------------------------------------------------------------------------------------------
# | epoch  16 |     0 /    1 batches |Train loss    0.706 | AUROC    0.543 | AUPRC    0.166
# | epoch  16 | total_loss    0.706
# ----------------------------------------------------------------------------------------------------
# | end of epoch  16 | valid AUROC    0.534 | valid AUPRC    0.156
# ----------------------------------------------------------------------------------------------------
# | end of epoch  16 | test  AUROC    0.503 | test  AUPRC    0.148
# ----------------------------------------------------------------------------------------------------
# | epoch  17 |     0 /    1 batches |Train loss    0.704 | AUROC    0.547 | AUPRC    0.168
# | epoch  17 | total_loss    0.704
# ----------------------------------------------------------------------------------------------------
# | end of epoch  17 | valid AUROC    0.534 | valid AUPRC    0.156
# ----------------------------------------------------------------------------------------------------
# | end of epoch  17 | test  AUROC    0.503 | test  AUPRC    0.148
# ----------------------------------------------------------------------------------------------------
# | epoch  18 |     0 /    1 batches |Train loss    0.702 | AUROC    0.551 | AUPRC    0.170
# | epoch  18 | total_loss    0.702
# ----------------------------------------------------------------------------------------------------
# | end of epoch  18 | valid AUROC    0.534 | valid AUPRC    0.156
# ----------------------------------------------------------------------------------------------------
# | end of epoch  18 | test  AUROC    0.503 | test  AUPRC    0.148
# ----------------------------------------------------------------------------------------------------
# | epoch  19 |     0 /    1 batches |Train loss    0.700 | AUROC    0.554 | AUPRC    0.172
# | epoch  19 | total_loss    0.700
# ----------------------------------------------------------------------------------------------------
# | end of epoch  19 | valid AUROC    0.535 | valid AUPRC    0.156
# ----------------------------------------------------------------------------------------------------
# | end of epoch  19 | test  AUROC    0.503 | test  AUPRC    0.148
# ----------------------------------------------------------------------------------------------------
# | epoch  20 |     0 /    1 batches |Train loss    0.698 | AUROC    0.558 | AUPRC    0.174
# | epoch  20 | total_loss    0.698
# ----------------------------------------------------------------------------------------------------
# | end of epoch  20 | valid AUROC    0.535 | valid AUPRC    0.156
# ----------------------------------------------------------------------------------------------------
# | end of epoch  20 | test  AUROC    0.503 | test  AUPRC    0.148
# ----------------------------------------------------------------------------------------------------
# | epoch  21 |     0 /    1 batches |Train loss    0.696 | AUROC    0.561 | AUPRC    0.176
# | epoch  21 | total_loss    0.696
# ----------------------------------------------------------------------------------------------------
# | end of epoch  21 | valid AUROC    0.535 | valid AUPRC    0.156
# ----------------------------------------------------------------------------------------------------
# | end of epoch  21 | test  AUROC    0.504 | test  AUPRC    0.148
# ----------------------------------------------------------------------------------------------------
# | epoch  22 |     0 /    1 batches |Train loss    0.694 | AUROC    0.565 | AUPRC    0.178
# | epoch  22 | total_loss    0.694
# ----------------------------------------------------------------------------------------------------
# | end of epoch  22 | valid AUROC    0.535 | valid AUPRC    0.156
# ----------------------------------------------------------------------------------------------------
# | end of epoch  22 | test  AUROC    0.504 | test  AUPRC    0.148
# ----------------------------------------------------------------------------------------------------
# | epoch  23 |     0 /    1 batches |Train loss    0.692 | AUROC    0.569 | AUPRC    0.180
# | epoch  23 | total_loss    0.692
# ----------------------------------------------------------------------------------------------------
# | end of epoch  23 | valid AUROC    0.536 | valid AUPRC    0.156
# ----------------------------------------------------------------------------------------------------
# | end of epoch  23 | test  AUROC    0.504 | test  AUPRC    0.148
# ----------------------------------------------------------------------------------------------------
# | epoch  24 |     0 /    1 batches |Train loss    0.690 | AUROC    0.572 | AUPRC    0.182
# | epoch  24 | total_loss    0.690
# ----------------------------------------------------------------------------------------------------
# | end of epoch  24 | valid AUROC    0.536 | valid AUPRC    0.157
# ----------------------------------------------------------------------------------------------------
# | end of epoch  24 | test  AUROC    0.504 | test  AUPRC    0.148
# ----------------------------------------------------------------------------------------------------
# | epoch  25 |     0 /    1 batches |Train loss    0.688 | AUROC    0.576 | AUPRC    0.184
# | epoch  25 | total_loss    0.688
# ----------------------------------------------------------------------------------------------------
# | end of epoch  25 | valid AUROC    0.536 | valid AUPRC    0.157
# ----------------------------------------------------------------------------------------------------
# | end of epoch  25 | test  AUROC    0.504 | test  AUPRC    0.148
# ----------------------------------------------------------------------------------------------------
# | epoch  26 |     0 /    1 batches |Train loss    0.686 | AUROC    0.580 | AUPRC    0.186
# | epoch  26 | total_loss    0.686
# ----------------------------------------------------------------------------------------------------
# | end of epoch  26 | valid AUROC    0.537 | valid AUPRC    0.157
# ----------------------------------------------------------------------------------------------------
# | end of epoch  26 | test  AUROC    0.505 | test  AUPRC    0.149
# ----------------------------------------------------------------------------------------------------
# | epoch  27 |     0 /    1 batches |Train loss    0.683 | AUROC    0.583 | AUPRC    0.188
# | epoch  27 | total_loss    0.683
# ----------------------------------------------------------------------------------------------------
# | end of epoch  27 | valid AUROC    0.537 | valid AUPRC    0.157
# ----------------------------------------------------------------------------------------------------
# | end of epoch  27 | test  AUROC    0.505 | test  AUPRC    0.149
# ----------------------------------------------------------------------------------------------------
# | epoch  28 |     0 /    1 batches |Train loss    0.681 | AUROC    0.587 | AUPRC    0.191
# | epoch  28 | total_loss    0.681
# ----------------------------------------------------------------------------------------------------
# | end of epoch  28 | valid AUROC    0.537 | valid AUPRC    0.157
# ----------------------------------------------------------------------------------------------------
# | end of epoch  28 | test  AUROC    0.505 | test  AUPRC    0.149
# ----------------------------------------------------------------------------------------------------
# | epoch  29 |     0 /    1 batches |Train loss    0.679 | AUROC    0.591 | AUPRC    0.193
# | epoch  29 | total_loss    0.679
# ----------------------------------------------------------------------------------------------------
# | end of epoch  29 | valid AUROC    0.538 | valid AUPRC    0.157
# ----------------------------------------------------------------------------------------------------
# | end of epoch  29 | test  AUROC    0.506 | test  AUPRC    0.149
# ----------------------------------------------------------------------------------------------------
# | epoch  30 |     0 /    1 batches |Train loss    0.677 | AUROC    0.594 | AUPRC    0.196
# | epoch  30 | total_loss    0.677
# ----------------------------------------------------------------------------------------------------
# | end of epoch  30 | valid AUROC    0.538 | valid AUPRC    0.157
# ----------------------------------------------------------------------------------------------------
# | end of epoch  30 | test  AUROC    0.506 | test  AUPRC    0.149
# ----------------------------------------------------------------------------------------------------
# | epoch  31 |     0 /    1 batches |Train loss    0.675 | AUROC    0.598 | AUPRC    0.198
# | epoch  31 | total_loss    0.675
# ----------------------------------------------------------------------------------------------------
# | end of epoch  31 | valid AUROC    0.538 | valid AUPRC    0.157
# ----------------------------------------------------------------------------------------------------
# | end of epoch  31 | test  AUROC    0.506 | test  AUPRC    0.149
# ----------------------------------------------------------------------------------------------------
# | epoch  32 |     0 /    1 batches |Train loss    0.673 | AUROC    0.602 | AUPRC    0.201
# | epoch  32 | total_loss    0.673
# ----------------------------------------------------------------------------------------------------
# | end of epoch  32 | valid AUROC    0.539 | valid AUPRC    0.158
# ----------------------------------------------------------------------------------------------------
# | end of epoch  32 | test  AUROC    0.507 | test  AUPRC    0.149
# ----------------------------------------------------------------------------------------------------
# | epoch  33 |     0 /    1 batches |Train loss    0.671 | AUROC    0.605 | AUPRC    0.203
# | epoch  33 | total_loss    0.671
# ----------------------------------------------------------------------------------------------------
# | end of epoch  33 | valid AUROC    0.539 | valid AUPRC    0.158
# ----------------------------------------------------------------------------------------------------
# | end of epoch  33 | test  AUROC    0.507 | test  AUPRC    0.150
# ----------------------------------------------------------------------------------------------------
# | epoch  34 |     0 /    1 batches |Train loss    0.669 | AUROC    0.609 | AUPRC    0.206
# | epoch  34 | total_loss    0.669
# ----------------------------------------------------------------------------------------------------
# | end of epoch  34 | valid AUROC    0.539 | valid AUPRC    0.158
# ----------------------------------------------------------------------------------------------------
# | end of epoch  34 | test  AUROC    0.507 | test  AUPRC    0.150
# ----------------------------------------------------------------------------------------------------
# | epoch  35 |     0 /    1 batches |Train loss    0.666 | AUROC    0.613 | AUPRC    0.208
# | epoch  35 | total_loss    0.666
# ----------------------------------------------------------------------------------------------------
# | end of epoch  35 | valid AUROC    0.540 | valid AUPRC    0.158
# ----------------------------------------------------------------------------------------------------
# | end of epoch  35 | test  AUROC    0.508 | test  AUPRC    0.150
# ----------------------------------------------------------------------------------------------------
# | epoch  36 |     0 /    1 batches |Train loss    0.664 | AUROC    0.617 | AUPRC    0.211
# | epoch  36 | total_loss    0.664
# ----------------------------------------------------------------------------------------------------
# | end of epoch  36 | valid AUROC    0.540 | valid AUPRC    0.158
# ----------------------------------------------------------------------------------------------------
# | end of epoch  36 | test  AUROC    0.508 | test  AUPRC    0.150
# ----------------------------------------------------------------------------------------------------
# | epoch  37 |     0 /    1 batches |Train loss    0.662 | AUROC    0.620 | AUPRC    0.214
# | epoch  37 | total_loss    0.662
# ----------------------------------------------------------------------------------------------------
# | end of epoch  37 | valid AUROC    0.541 | valid AUPRC    0.158
# ----------------------------------------------------------------------------------------------------
# | end of epoch  37 | test  AUROC    0.509 | test  AUPRC    0.150
# ----------------------------------------------------------------------------------------------------
# | epoch  38 |     0 /    1 batches |Train loss    0.660 | AUROC    0.624 | AUPRC    0.217
# | epoch  38 | total_loss    0.660
# ----------------------------------------------------------------------------------------------------
# | end of epoch  38 | valid AUROC    0.541 | valid AUPRC    0.158
# ----------------------------------------------------------------------------------------------------
# | end of epoch  38 | test  AUROC    0.509 | test  AUPRC    0.150
# ----------------------------------------------------------------------------------------------------
# | epoch  39 |     0 /    1 batches |Train loss    0.658 | AUROC    0.628 | AUPRC    0.220
# | epoch  39 | total_loss    0.658
# ----------------------------------------------------------------------------------------------------
# | end of epoch  39 | valid AUROC    0.542 | valid AUPRC    0.158
# ----------------------------------------------------------------------------------------------------
# | end of epoch  39 | test  AUROC    0.509 | test  AUPRC    0.151
# ----------------------------------------------------------------------------------------------------
# | epoch  40 |     0 /    1 batches |Train loss    0.655 | AUROC    0.632 | AUPRC    0.223
# | epoch  40 | total_loss    0.655
# ----------------------------------------------------------------------------------------------------
# | end of epoch  40 | valid AUROC    0.542 | valid AUPRC    0.159
# ----------------------------------------------------------------------------------------------------
# | end of epoch  40 | test  AUROC    0.510 | test  AUPRC    0.151
# ----------------------------------------------------------------------------------------------------
# | epoch  41 |     0 /    1 batches |Train loss    0.653 | AUROC    0.635 | AUPRC    0.226
# | epoch  41 | total_loss    0.653
# ----------------------------------------------------------------------------------------------------
# | end of epoch  41 | valid AUROC    0.543 | valid AUPRC    0.159
# ----------------------------------------------------------------------------------------------------
# | end of epoch  41 | test  AUROC    0.510 | test  AUPRC    0.151
# ----------------------------------------------------------------------------------------------------
# | epoch  42 |     0 /    1 batches |Train loss    0.651 | AUROC    0.639 | AUPRC    0.229
# | epoch  42 | total_loss    0.651
# ----------------------------------------------------------------------------------------------------
# | end of epoch  42 | valid AUROC    0.543 | valid AUPRC    0.159
# ----------------------------------------------------------------------------------------------------
# | end of epoch  42 | test  AUROC    0.511 | test  AUPRC    0.151
# ----------------------------------------------------------------------------------------------------
# | epoch  43 |     0 /    1 batches |Train loss    0.649 | AUROC    0.643 | AUPRC    0.232
# | epoch  43 | total_loss    0.649
# ----------------------------------------------------------------------------------------------------
# | end of epoch  43 | valid AUROC    0.544 | valid AUPRC    0.159
# ----------------------------------------------------------------------------------------------------
# | end of epoch  43 | test  AUROC    0.511 | test  AUPRC    0.152
# ----------------------------------------------------------------------------------------------------
# | epoch  44 |     0 /    1 batches |Train loss    0.647 | AUROC    0.647 | AUPRC    0.235
# | epoch  44 | total_loss    0.647
# ----------------------------------------------------------------------------------------------------
# | end of epoch  44 | valid AUROC    0.544 | valid AUPRC    0.159
# ----------------------------------------------------------------------------------------------------
# | end of epoch  44 | test  AUROC    0.512 | test  AUPRC    0.152
# ----------------------------------------------------------------------------------------------------
# | epoch  45 |     0 /    1 batches |Train loss    0.644 | AUROC    0.651 | AUPRC    0.239
# | epoch  45 | total_loss    0.644
# ----------------------------------------------------------------------------------------------------
# | end of epoch  45 | valid AUROC    0.545 | valid AUPRC    0.160
# ----------------------------------------------------------------------------------------------------
# | end of epoch  45 | test  AUROC    0.512 | test  AUPRC    0.152
# ----------------------------------------------------------------------------------------------------
# | epoch  46 |     0 /    1 batches |Train loss    0.642 | AUROC    0.654 | AUPRC    0.242
# | epoch  46 | total_loss    0.642
# ----------------------------------------------------------------------------------------------------
# | end of epoch  46 | valid AUROC    0.545 | valid AUPRC    0.160
# ----------------------------------------------------------------------------------------------------
# | end of epoch  46 | test  AUROC    0.513 | test  AUPRC    0.152
# ----------------------------------------------------------------------------------------------------
# | epoch  47 |     0 /    1 batches |Train loss    0.640 | AUROC    0.658 | AUPRC    0.246
# | epoch  47 | total_loss    0.640
# ----------------------------------------------------------------------------------------------------
# | end of epoch  47 | valid AUROC    0.546 | valid AUPRC    0.160
# ----------------------------------------------------------------------------------------------------
# | end of epoch  47 | test  AUROC    0.514 | test  AUPRC    0.153
# ----------------------------------------------------------------------------------------------------
# | epoch  48 |     0 /    1 batches |Train loss    0.637 | AUROC    0.662 | AUPRC    0.249
# | epoch  48 | total_loss    0.637
# ----------------------------------------------------------------------------------------------------
# | end of epoch  48 | valid AUROC    0.546 | valid AUPRC    0.160
# ----------------------------------------------------------------------------------------------------
# | end of epoch  48 | test  AUROC    0.514 | test  AUPRC    0.153
# ----------------------------------------------------------------------------------------------------
# | epoch  49 |     0 /    1 batches |Train loss    0.635 | AUROC    0.666 | AUPRC    0.253
# | epoch  49 | total_loss    0.635
# ----------------------------------------------------------------------------------------------------
# | end of epoch  49 | valid AUROC    0.547 | valid AUPRC    0.160
# ----------------------------------------------------------------------------------------------------
# | end of epoch  49 | test  AUROC    0.515 | test  AUPRC    0.153
# ----------------------------------------------------------------------------------------------------
# | epoch  50 |     0 /    1 batches |Train loss    0.633 | AUROC    0.669 | AUPRC    0.256
# | epoch  50 | total_loss    0.633
# ----------------------------------------------------------------------------------------------------
# | end of epoch  50 | valid AUROC    0.548 | valid AUPRC    0.161
# ----------------------------------------------------------------------------------------------------
# | end of epoch  50 | test  AUROC    0.516 | test  AUPRC    0.154
# ----------------------------------------------------------------------------------------------------
# | epoch  51 |     0 /    1 batches |Train loss    0.630 | AUROC    0.673 | AUPRC    0.260
# | epoch  51 | total_loss    0.630
# ----------------------------------------------------------------------------------------------------
# | end of epoch  51 | valid AUROC    0.549 | valid AUPRC    0.161
# ----------------------------------------------------------------------------------------------------
# | end of epoch  51 | test  AUROC    0.516 | test  AUPRC    0.154
# ----------------------------------------------------------------------------------------------------
# | epoch  52 |     0 /    1 batches |Train loss    0.628 | AUROC    0.677 | AUPRC    0.264
# | epoch  52 | total_loss    0.628
# ----------------------------------------------------------------------------------------------------
# | end of epoch  52 | valid AUROC    0.549 | valid AUPRC    0.161
# ----------------------------------------------------------------------------------------------------
# | end of epoch  52 | test  AUROC    0.517 | test  AUPRC    0.154
# ----------------------------------------------------------------------------------------------------
# | epoch  53 |     0 /    1 batches |Train loss    0.625 | AUROC    0.681 | AUPRC    0.268
# | epoch  53 | total_loss    0.625
# ----------------------------------------------------------------------------------------------------
# | end of epoch  53 | valid AUROC    0.550 | valid AUPRC    0.161
# ----------------------------------------------------------------------------------------------------
# | end of epoch  53 | test  AUROC    0.518 | test  AUPRC    0.154
# ----------------------------------------------------------------------------------------------------
# | epoch  54 |     0 /    1 batches |Train loss    0.623 | AUROC    0.684 | AUPRC    0.272
# | epoch  54 | total_loss    0.623
# ----------------------------------------------------------------------------------------------------
# | end of epoch  54 | valid AUROC    0.551 | valid AUPRC    0.162
# ----------------------------------------------------------------------------------------------------
# | end of epoch  54 | test  AUROC    0.518 | test  AUPRC    0.155
# ----------------------------------------------------------------------------------------------------
# | epoch  55 |     0 /    1 batches |Train loss    0.620 | AUROC    0.688 | AUPRC    0.276
# | epoch  55 | total_loss    0.620
# ----------------------------------------------------------------------------------------------------
# | end of epoch  55 | valid AUROC    0.551 | valid AUPRC    0.162
# ----------------------------------------------------------------------------------------------------
# | end of epoch  55 | test  AUROC    0.519 | test  AUPRC    0.155
# ----------------------------------------------------------------------------------------------------
# | epoch  56 |     0 /    1 batches |Train loss    0.618 | AUROC    0.692 | AUPRC    0.280
# | epoch  56 | total_loss    0.618
# ----------------------------------------------------------------------------------------------------
# | end of epoch  56 | valid AUROC    0.552 | valid AUPRC    0.163
# ----------------------------------------------------------------------------------------------------
# | end of epoch  56 | test  AUROC    0.520 | test  AUPRC    0.156
# ----------------------------------------------------------------------------------------------------
# | epoch  57 |     0 /    1 batches |Train loss    0.615 | AUROC    0.696 | AUPRC    0.284
# | epoch  57 | total_loss    0.615
# ----------------------------------------------------------------------------------------------------
# | end of epoch  57 | valid AUROC    0.553 | valid AUPRC    0.163
# ----------------------------------------------------------------------------------------------------
# | end of epoch  57 | test  AUROC    0.521 | test  AUPRC    0.156
# ----------------------------------------------------------------------------------------------------
# | epoch  58 |     0 /    1 batches |Train loss    0.613 | AUROC    0.700 | AUPRC    0.289
# | epoch  58 | total_loss    0.613
# ----------------------------------------------------------------------------------------------------
# | end of epoch  58 | valid AUROC    0.553 | valid AUPRC    0.163
# ----------------------------------------------------------------------------------------------------
# | end of epoch  58 | test  AUROC    0.522 | test  AUPRC    0.156
# ----------------------------------------------------------------------------------------------------
# | epoch  59 |     0 /    1 batches |Train loss    0.610 | AUROC    0.703 | AUPRC    0.293
# | epoch  59 | total_loss    0.610
# ----------------------------------------------------------------------------------------------------
# | end of epoch  59 | valid AUROC    0.554 | valid AUPRC    0.164
# ----------------------------------------------------------------------------------------------------
# | end of epoch  59 | test  AUROC    0.523 | test  AUPRC    0.157
# ----------------------------------------------------------------------------------------------------
# | epoch  60 |     0 /    1 batches |Train loss    0.608 | AUROC    0.707 | AUPRC    0.298
# | epoch  60 | total_loss    0.608
# ----------------------------------------------------------------------------------------------------
# | end of epoch  60 | valid AUROC    0.555 | valid AUPRC    0.164
# ----------------------------------------------------------------------------------------------------
# | end of epoch  60 | test  AUROC    0.523 | test  AUPRC    0.157
# ----------------------------------------------------------------------------------------------------
# | epoch  61 |     0 /    1 batches |Train loss    0.605 | AUROC    0.711 | AUPRC    0.302
# | epoch  61 | total_loss    0.605
# ----------------------------------------------------------------------------------------------------
# | end of epoch  61 | valid AUROC    0.556 | valid AUPRC    0.164
# ----------------------------------------------------------------------------------------------------
# | end of epoch  61 | test  AUROC    0.524 | test  AUPRC    0.158
# ----------------------------------------------------------------------------------------------------
# | epoch  62 |     0 /    1 batches |Train loss    0.602 | AUROC    0.715 | AUPRC    0.307
# | epoch  62 | total_loss    0.602
# ----------------------------------------------------------------------------------------------------
# | end of epoch  62 | valid AUROC    0.557 | valid AUPRC    0.165
# ----------------------------------------------------------------------------------------------------
# | end of epoch  62 | test  AUROC    0.525 | test  AUPRC    0.158
# ----------------------------------------------------------------------------------------------------
# | epoch  63 |     0 /    1 batches |Train loss    0.600 | AUROC    0.719 | AUPRC    0.312
# | epoch  63 | total_loss    0.600
# ----------------------------------------------------------------------------------------------------
# | end of epoch  63 | valid AUROC    0.558 | valid AUPRC    0.165
# ----------------------------------------------------------------------------------------------------
# | end of epoch  63 | test  AUROC    0.526 | test  AUPRC    0.159
# ----------------------------------------------------------------------------------------------------
# | epoch  64 |     0 /    1 batches |Train loss    0.597 | AUROC    0.723 | AUPRC    0.317
# | epoch  64 | total_loss    0.597
# ----------------------------------------------------------------------------------------------------
# | end of epoch  64 | valid AUROC    0.559 | valid AUPRC    0.166
# ----------------------------------------------------------------------------------------------------
# | end of epoch  64 | test  AUROC    0.527 | test  AUPRC    0.159
# ----------------------------------------------------------------------------------------------------
# | epoch  65 |     0 /    1 batches |Train loss    0.594 | AUROC    0.727 | AUPRC    0.322
# | epoch  65 | total_loss    0.594
# ----------------------------------------------------------------------------------------------------
# | end of epoch  65 | valid AUROC    0.560 | valid AUPRC    0.166
# ----------------------------------------------------------------------------------------------------
# | end of epoch  65 | test  AUROC    0.529 | test  AUPRC    0.160
# ----------------------------------------------------------------------------------------------------
# | epoch  66 |     0 /    1 batches |Train loss    0.591 | AUROC    0.731 | AUPRC    0.328
# | epoch  66 | total_loss    0.591
# ----------------------------------------------------------------------------------------------------
# | end of epoch  66 | valid AUROC    0.561 | valid AUPRC    0.167
# ----------------------------------------------------------------------------------------------------
# | end of epoch  66 | test  AUROC    0.530 | test  AUPRC    0.160
# ----------------------------------------------------------------------------------------------------
# | epoch  67 |     0 /    1 batches |Train loss    0.588 | AUROC    0.735 | AUPRC    0.333
# | epoch  67 | total_loss    0.588
# ----------------------------------------------------------------------------------------------------
# | end of epoch  67 | valid AUROC    0.562 | valid AUPRC    0.167
# ----------------------------------------------------------------------------------------------------
# | end of epoch  67 | test  AUROC    0.531 | test  AUPRC    0.161
# ----------------------------------------------------------------------------------------------------
# | epoch  68 |     0 /    1 batches |Train loss    0.585 | AUROC    0.739 | AUPRC    0.339
# | epoch  68 | total_loss    0.585
# ----------------------------------------------------------------------------------------------------
# | end of epoch  68 | valid AUROC    0.563 | valid AUPRC    0.168
# ----------------------------------------------------------------------------------------------------
# | end of epoch  68 | test  AUROC    0.532 | test  AUPRC    0.161
# ----------------------------------------------------------------------------------------------------
# | epoch  69 |     0 /    1 batches |Train loss    0.582 | AUROC    0.743 | AUPRC    0.345
# | epoch  69 | total_loss    0.582
# ----------------------------------------------------------------------------------------------------
# | end of epoch  69 | valid AUROC    0.564 | valid AUPRC    0.168
# ----------------------------------------------------------------------------------------------------
# | end of epoch  69 | test  AUROC    0.533 | test  AUPRC    0.162
# ----------------------------------------------------------------------------------------------------
# | epoch  70 |     0 /    1 batches |Train loss    0.579 | AUROC    0.747 | AUPRC    0.351
# | epoch  70 | total_loss    0.579
# ----------------------------------------------------------------------------------------------------
# | end of epoch  70 | valid AUROC    0.565 | valid AUPRC    0.169
# ----------------------------------------------------------------------------------------------------
# | end of epoch  70 | test  AUROC    0.535 | test  AUPRC    0.163
# ----------------------------------------------------------------------------------------------------
# | epoch  71 |     0 /    1 batches |Train loss    0.577 | AUROC    0.751 | AUPRC    0.357
# | epoch  71 | total_loss    0.577
# ----------------------------------------------------------------------------------------------------
# | end of epoch  71 | valid AUROC    0.566 | valid AUPRC    0.170
# ----------------------------------------------------------------------------------------------------
# | end of epoch  71 | test  AUROC    0.536 | test  AUPRC    0.164
# ----------------------------------------------------------------------------------------------------
# | epoch  72 |     0 /    1 batches |Train loss    0.573 | AUROC    0.756 | AUPRC    0.363
# | epoch  72 | total_loss    0.573
# ----------------------------------------------------------------------------------------------------
# | end of epoch  72 | valid AUROC    0.568 | valid AUPRC    0.171
# ----------------------------------------------------------------------------------------------------
# | end of epoch  72 | test  AUROC    0.538 | test  AUPRC    0.164
# ----------------------------------------------------------------------------------------------------
# | epoch  73 |     0 /    1 batches |Train loss    0.570 | AUROC    0.760 | AUPRC    0.370
# | epoch  73 | total_loss    0.570
# ----------------------------------------------------------------------------------------------------
# | end of epoch  73 | valid AUROC    0.569 | valid AUPRC    0.171
# ----------------------------------------------------------------------------------------------------
# | end of epoch  73 | test  AUROC    0.539 | test  AUPRC    0.165
# ----------------------------------------------------------------------------------------------------
# | epoch  74 |     0 /    1 batches |Train loss    0.567 | AUROC    0.764 | AUPRC    0.377
# | epoch  74 | total_loss    0.567
# ----------------------------------------------------------------------------------------------------
# | end of epoch  74 | valid AUROC    0.570 | valid AUPRC    0.172
# ----------------------------------------------------------------------------------------------------
# | end of epoch  74 | test  AUROC    0.541 | test  AUPRC    0.166
# ----------------------------------------------------------------------------------------------------
# | epoch  75 |     0 /    1 batches |Train loss    0.564 | AUROC    0.768 | AUPRC    0.384
# | epoch  75 | total_loss    0.564
# ----------------------------------------------------------------------------------------------------
# | end of epoch  75 | valid AUROC    0.571 | valid AUPRC    0.173
# ----------------------------------------------------------------------------------------------------
# | end of epoch  75 | test  AUROC    0.542 | test  AUPRC    0.167
# ----------------------------------------------------------------------------------------------------
# | epoch  76 |     0 /    1 batches |Train loss    0.561 | AUROC    0.772 | AUPRC    0.391
# | epoch  76 | total_loss    0.561
# ----------------------------------------------------------------------------------------------------
# | end of epoch  76 | valid AUROC    0.572 | valid AUPRC    0.174
# ----------------------------------------------------------------------------------------------------
# | end of epoch  76 | test  AUROC    0.544 | test  AUPRC    0.168
# ----------------------------------------------------------------------------------------------------
# | epoch  77 |     0 /    1 batches |Train loss    0.558 | AUROC    0.776 | AUPRC    0.398
# | epoch  77 | total_loss    0.558
# ----------------------------------------------------------------------------------------------------
# | end of epoch  77 | valid AUROC    0.574 | valid AUPRC    0.175
# ----------------------------------------------------------------------------------------------------
# | end of epoch  77 | test  AUROC    0.546 | test  AUPRC    0.169
# ----------------------------------------------------------------------------------------------------
# | epoch  78 |     0 /    1 batches |Train loss    0.555 | AUROC    0.781 | AUPRC    0.406
# | epoch  78 | total_loss    0.555
# ----------------------------------------------------------------------------------------------------
# | end of epoch  78 | valid AUROC    0.575 | valid AUPRC    0.176
# ----------------------------------------------------------------------------------------------------
# | end of epoch  78 | test  AUROC    0.548 | test  AUPRC    0.170
# ----------------------------------------------------------------------------------------------------
# | epoch  79 |     0 /    1 batches |Train loss    0.552 | AUROC    0.784 | AUPRC    0.413
# | epoch  79 | total_loss    0.552
# ----------------------------------------------------------------------------------------------------
# | end of epoch  79 | valid AUROC    0.577 | valid AUPRC    0.177
# ----------------------------------------------------------------------------------------------------
# | end of epoch  79 | test  AUROC    0.550 | test  AUPRC    0.171
# ----------------------------------------------------------------------------------------------------
# | epoch  80 |     0 /    1 batches |Train loss    0.549 | AUROC    0.788 | AUPRC    0.421
# | epoch  80 | total_loss    0.549
# ----------------------------------------------------------------------------------------------------
# | end of epoch  80 | valid AUROC    0.578 | valid AUPRC    0.178
# ----------------------------------------------------------------------------------------------------
# | end of epoch  80 | test  AUROC    0.552 | test  AUPRC    0.172
# ----------------------------------------------------------------------------------------------------
# | epoch  81 |     0 /    1 batches |Train loss    0.546 | AUROC    0.792 | AUPRC    0.428
# | epoch  81 | total_loss    0.546
# ----------------------------------------------------------------------------------------------------
# | end of epoch  81 | valid AUROC    0.580 | valid AUPRC    0.179
# ----------------------------------------------------------------------------------------------------
# | end of epoch  81 | test  AUROC    0.553 | test  AUPRC    0.173
# ----------------------------------------------------------------------------------------------------
# | epoch  82 |     0 /    1 batches |Train loss    0.543 | AUROC    0.796 | AUPRC    0.436
# | epoch  82 | total_loss    0.543
# ----------------------------------------------------------------------------------------------------
# | end of epoch  82 | valid AUROC    0.582 | valid AUPRC    0.180
# ----------------------------------------------------------------------------------------------------
# | end of epoch  82 | test  AUROC    0.555 | test  AUPRC    0.174
# ----------------------------------------------------------------------------------------------------
# | epoch  83 |     0 /    1 batches |Train loss    0.540 | AUROC    0.799 | AUPRC    0.443
# | epoch  83 | total_loss    0.540
# ----------------------------------------------------------------------------------------------------
# | end of epoch  83 | valid AUROC    0.584 | valid AUPRC    0.181
# ----------------------------------------------------------------------------------------------------
# | end of epoch  83 | test  AUROC    0.557 | test  AUPRC    0.175
# ----------------------------------------------------------------------------------------------------
# | epoch  84 |     0 /    1 batches |Train loss    0.537 | AUROC    0.803 | AUPRC    0.451
# | epoch  84 | total_loss    0.537
# ----------------------------------------------------------------------------------------------------
# | end of epoch  84 | valid AUROC    0.585 | valid AUPRC    0.183
# ----------------------------------------------------------------------------------------------------
# | end of epoch  84 | test  AUROC    0.559 | test  AUPRC    0.177
# ----------------------------------------------------------------------------------------------------
# | epoch  85 |     0 /    1 batches |Train loss    0.534 | AUROC    0.806 | AUPRC    0.458
# | epoch  85 | total_loss    0.534
# ----------------------------------------------------------------------------------------------------
# | end of epoch  85 | valid AUROC    0.587 | valid AUPRC    0.184
# ----------------------------------------------------------------------------------------------------
# | end of epoch  85 | test  AUROC    0.561 | test  AUPRC    0.178
# ----------------------------------------------------------------------------------------------------
# | epoch  86 |     0 /    1 batches |Train loss    0.530 | AUROC    0.810 | AUPRC    0.465
# | epoch  86 | total_loss    0.530
# ----------------------------------------------------------------------------------------------------
# | end of epoch  86 | valid AUROC    0.589 | valid AUPRC    0.186
# ----------------------------------------------------------------------------------------------------
# | end of epoch  86 | test  AUROC    0.563 | test  AUPRC    0.179
# ----------------------------------------------------------------------------------------------------
# | epoch  87 |     0 /    1 batches |Train loss    0.527 | AUROC    0.813 | AUPRC    0.472
# ...
# | end of epoch 619 | valid AUROC    0.865 | valid AUPRC    0.571
# ----------------------------------------------------------------------------------------------------
# | end of epoch 619 | test  AUROC    0.866 | test  AUPRC    0.580
# ----------------------------------------------------------------------------------------------------
# | epoch 620 |     0 /    1 batches |Train loss    0.124 | AUROC    1.000 | AUPRC    1.000
# | epoch 620 | total_loss    0.124
# ----------------------------------------------------------------------------------------------------
# | end of epoch 620 | valid AUROC    0.865 | valid AUPRC    0.571
# ----------------------------------------------------------------------------------------------------
# | end of epoch 620 | test  AUROC    0.867 | test  AUPRC    0.580
# ----------------------------------------------------------------------------------------------------
# | epoch 621 |     0 /    1 batches |Train loss    0.124 | AUROC    1.000 | AUPRC    1.000
# | epoch 621 | total_loss    0.124
# ----------------------------------------------------------------------------------------------------
# | end of epoch 621 | valid AUROC    0.865 | valid AUPRC    0.571
# ----------------------------------------------------------------------------------------------------
# | end of epoch 621 | test  AUROC    0.867 | test  AUPRC    0.580
# ----------------------------------------------------------------------------------------------------
# | epoch 622 |     0 /    1 batches |Train loss    0.124 | AUROC    1.000 | AUPRC    1.000
# | epoch 622 | total_loss    0.124
# ----------------------------------------------------------------------------------------------------
# | end of epoch 622 | valid AUROC    0.865 | valid AUPRC    0.571
# ----------------------------------------------------------------------------------------------------
# | end of epoch 622 | test  AUROC    0.867 | test  AUPRC    0.580
# ----------------------------------------------------------------------------------------------------
# | epoch 623 |     0 /    1 batches |Train loss    0.123 | AUROC    1.000 | AUPRC    1.000
# | epoch 623 | total_loss    0.123
# ----------------------------------------------------------------------------------------------------
# | end of epoch 623 | valid AUROC    0.865 | valid AUPRC    0.571
# ----------------------------------------------------------------------------------------------------
# | end of epoch 623 | test  AUROC    0.867 | test  AUPRC    0.580
# ----------------------------------------------------------------------------------------------------
# | epoch 624 |     0 /    1 batches |Train loss    0.123 | AUROC    1.000 | AUPRC    1.000
# | epoch 624 | total_loss    0.123
# ----------------------------------------------------------------------------------------------------
# | end of epoch 624 | valid AUROC    0.866 | valid AUPRC    0.571
# ----------------------------------------------------------------------------------------------------
# | end of epoch 624 | test  AUROC    0.867 | test  AUPRC    0.580
# ----------------------------------------------------------------------------------------------------
# | epoch 625 |     0 /    1 batches |Train loss    0.123 | AUROC    1.000 | AUPRC    1.000
# | epoch 625 | total_loss    0.123
# ----------------------------------------------------------------------------------------------------
# | end of epoch 625 | valid AUROC    0.866 | valid AUPRC    0.571
# ----------------------------------------------------------------------------------------------------
# | end of epoch 625 | test  AUROC    0.867 | test  AUPRC    0.580
# ----------------------------------------------------------------------------------------------------
# | epoch 626 |     0 /    1 batches |Train loss    0.123 | AUROC    1.000 | AUPRC    1.000
# | epoch 626 | total_loss    0.123
# ----------------------------------------------------------------------------------------------------
# | end of epoch 626 | valid AUROC    0.866 | valid AUPRC    0.571
# ----------------------------------------------------------------------------------------------------
# | end of epoch 626 | test  AUROC    0.867 | test  AUPRC    0.580
# ----------------------------------------------------------------------------------------------------
# | epoch 627 |     0 /    1 batches |Train loss    0.123 | AUROC    1.000 | AUPRC    1.000
# | epoch 627 | total_loss    0.123
# ----------------------------------------------------------------------------------------------------
# | end of epoch 627 | valid AUROC    0.866 | valid AUPRC    0.571
# ----------------------------------------------------------------------------------------------------
# | end of epoch 627 | test  AUROC    0.867 | test  AUPRC    0.580
# ----------------------------------------------------------------------------------------------------
# | epoch 628 |     0 /    1 batches |Train loss    0.123 | AUROC    1.000 | AUPRC    1.000
# | epoch 628 | total_loss    0.123
# ----------------------------------------------------------------------------------------------------
# | end of epoch 628 | valid AUROC    0.866 | valid AUPRC    0.571
# ----------------------------------------------------------------------------------------------------
# | end of epoch 628 | test  AUROC    0.867 | test  AUPRC    0.581
# ----------------------------------------------------------------------------------------------------
# | epoch 629 |     0 /    1 batches |Train loss    0.122 | AUROC    1.000 | AUPRC    1.000
# | epoch 629 | total_loss    0.122
# ----------------------------------------------------------------------------------------------------
# | end of epoch 629 | valid AUROC    0.866 | valid AUPRC    0.571
# ----------------------------------------------------------------------------------------------------
# | end of epoch 629 | test  AUROC    0.867 | test  AUPRC    0.581
# ----------------------------------------------------------------------------------------------------
# | epoch 630 |     0 /    1 batches |Train loss    0.122 | AUROC    1.000 | AUPRC    1.000
# | epoch 630 | total_loss    0.122
# ----------------------------------------------------------------------------------------------------
# | end of epoch 630 | valid AUROC    0.866 | valid AUPRC    0.571
# ----------------------------------------------------------------------------------------------------
# | end of epoch 630 | test  AUROC    0.867 | test  AUPRC    0.581
# ----------------------------------------------------------------------------------------------------
# | epoch 631 |     0 /    1 batches |Train loss    0.122 | AUROC    1.000 | AUPRC    1.000
# | epoch 631 | total_loss    0.122
# ----------------------------------------------------------------------------------------------------
# | end of epoch 631 | valid AUROC    0.866 | valid AUPRC    0.572
# ----------------------------------------------------------------------------------------------------
# | end of epoch 631 | test  AUROC    0.867 | test  AUPRC    0.581
# ----------------------------------------------------------------------------------------------------
# | epoch 632 |     0 /    1 batches |Train loss    0.122 | AUROC    1.000 | AUPRC    1.000
# | epoch 632 | total_loss    0.122
# ----------------------------------------------------------------------------------------------------
# | end of epoch 632 | valid AUROC    0.866 | valid AUPRC    0.572
# ----------------------------------------------------------------------------------------------------
# | end of epoch 632 | test  AUROC    0.867 | test  AUPRC    0.581
# ----------------------------------------------------------------------------------------------------
# | epoch 633 |     0 /    1 batches |Train loss    0.122 | AUROC    1.000 | AUPRC    1.000
# | epoch 633 | total_loss    0.122
# ----------------------------------------------------------------------------------------------------
# | end of epoch 633 | valid AUROC    0.866 | valid AUPRC    0.572
# ----------------------------------------------------------------------------------------------------
# | end of epoch 633 | test  AUROC    0.867 | test  AUPRC    0.581
# ----------------------------------------------------------------------------------------------------
# | epoch 634 |     0 /    1 batches |Train loss    0.122 | AUROC    1.000 | AUPRC    1.000
# | epoch 634 | total_loss    0.122
# ----------------------------------------------------------------------------------------------------
# | end of epoch 634 | valid AUROC    0.866 | valid AUPRC    0.572
# ----------------------------------------------------------------------------------------------------
# | end of epoch 634 | test  AUROC    0.867 | test  AUPRC    0.581
# ----------------------------------------------------------------------------------------------------
# | epoch 635 |     0 /    1 batches |Train loss    0.122 | AUROC    1.000 | AUPRC    1.000
# | epoch 635 | total_loss    0.122
# ----------------------------------------------------------------------------------------------------
# | end of epoch 635 | valid AUROC    0.866 | valid AUPRC    0.572
# ----------------------------------------------------------------------------------------------------
# | end of epoch 635 | test  AUROC    0.867 | test  AUPRC    0.581
# ----------------------------------------------------------------------------------------------------
# | epoch 636 |     0 /    1 batches |Train loss    0.121 | AUROC    1.000 | AUPRC    1.000
# | epoch 636 | total_loss    0.121
# ----------------------------------------------------------------------------------------------------
# | end of epoch 636 | valid AUROC    0.866 | valid AUPRC    0.572
# ----------------------------------------------------------------------------------------------------
# | end of epoch 636 | test  AUROC    0.867 | test  AUPRC    0.581
# ----------------------------------------------------------------------------------------------------
# | epoch 637 |     0 /    1 batches |Train loss    0.121 | AUROC    1.000 | AUPRC    1.000
# | epoch 637 | total_loss    0.121
# ----------------------------------------------------------------------------------------------------
# | end of epoch 637 | valid AUROC    0.866 | valid AUPRC    0.572
# ----------------------------------------------------------------------------------------------------
# | end of epoch 637 | test  AUROC    0.867 | test  AUPRC    0.581
# ----------------------------------------------------------------------------------------------------
# | epoch 638 |     0 /    1 batches |Train loss    0.121 | AUROC    1.000 | AUPRC    1.000
# | epoch 638 | total_loss    0.121
# ----------------------------------------------------------------------------------------------------
# | end of epoch 638 | valid AUROC    0.866 | valid AUPRC    0.572
# ----------------------------------------------------------------------------------------------------
# | end of epoch 638 | test  AUROC    0.867 | test  AUPRC    0.581
# ----------------------------------------------------------------------------------------------------
# | epoch 639 |     0 /    1 batches |Train loss    0.121 | AUROC    1.000 | AUPRC    1.000
# | epoch 639 | total_loss    0.121
# ----------------------------------------------------------------------------------------------------
# | end of epoch 639 | valid AUROC    0.866 | valid AUPRC    0.572
# ----------------------------------------------------------------------------------------------------
# | end of epoch 639 | test  AUROC    0.867 | test  AUPRC    0.581
# ----------------------------------------------------------------------------------------------------
# | epoch 640 |     0 /    1 batches |Train loss    0.121 | AUROC    1.000 | AUPRC    1.000
# | epoch 640 | total_loss    0.121
# ----------------------------------------------------------------------------------------------------
# | end of epoch 640 | valid AUROC    0.866 | valid AUPRC    0.572
# ----------------------------------------------------------------------------------------------------
# | end of epoch 640 | test  AUROC    0.867 | test  AUPRC    0.581
# ----------------------------------------------------------------------------------------------------
# | epoch 641 |     0 /    1 batches |Train loss    0.121 | AUROC    1.000 | AUPRC    1.000
# | epoch 641 | total_loss    0.121
# ----------------------------------------------------------------------------------------------------
# | end of epoch 641 | valid AUROC    0.866 | valid AUPRC    0.572
# ----------------------------------------------------------------------------------------------------
# | end of epoch 641 | test  AUROC    0.867 | test  AUPRC    0.582
# ----------------------------------------------------------------------------------------------------
# | epoch 642 |     0 /    1 batches |Train loss    0.120 | AUROC    1.000 | AUPRC    1.000
# | epoch 642 | total_loss    0.120
# ----------------------------------------------------------------------------------------------------
# | end of epoch 642 | valid AUROC    0.866 | valid AUPRC    0.572
# ----------------------------------------------------------------------------------------------------
# | end of epoch 642 | test  AUROC    0.867 | test  AUPRC    0.582
# ----------------------------------------------------------------------------------------------------
# | epoch 643 |     0 /    1 batches |Train loss    0.120 | AUROC    1.000 | AUPRC    1.000
# | epoch 643 | total_loss    0.120
# ----------------------------------------------------------------------------------------------------
# | end of epoch 643 | valid AUROC    0.866 | valid AUPRC    0.572
# ----------------------------------------------------------------------------------------------------
# | end of epoch 643 | test  AUROC    0.867 | test  AUPRC    0.582
# ----------------------------------------------------------------------------------------------------
# | epoch 644 |     0 /    1 batches |Train loss    0.120 | AUROC    1.000 | AUPRC    1.000
# | epoch 644 | total_loss    0.120
# ----------------------------------------------------------------------------------------------------
# | end of epoch 644 | valid AUROC    0.866 | valid AUPRC    0.572
# ----------------------------------------------------------------------------------------------------
# | end of epoch 644 | test  AUROC    0.867 | test  AUPRC    0.582
# ----------------------------------------------------------------------------------------------------
# | epoch 645 |     0 /    1 batches |Train loss    0.120 | AUROC    1.000 | AUPRC    1.000
# | epoch 645 | total_loss    0.120
# ----------------------------------------------------------------------------------------------------
# | end of epoch 645 | valid AUROC    0.866 | valid AUPRC    0.572
# ----------------------------------------------------------------------------------------------------
# | end of epoch 645 | test  AUROC    0.867 | test  AUPRC    0.582
# ----------------------------------------------------------------------------------------------------
# | epoch 646 |     0 /    1 batches |Train loss    0.120 | AUROC    1.000 | AUPRC    1.000
# | epoch 646 | total_loss    0.120
# ----------------------------------------------------------------------------------------------------
# | end of epoch 646 | valid AUROC    0.866 | valid AUPRC    0.572
# ----------------------------------------------------------------------------------------------------
# | end of epoch 646 | test  AUROC    0.867 | test  AUPRC    0.582
# ----------------------------------------------------------------------------------------------------
# | epoch 647 |     0 /    1 batches |Train loss    0.120 | AUROC    1.000 | AUPRC    1.000
# | epoch 647 | total_loss    0.120
# ----------------------------------------------------------------------------------------------------
# | end of epoch 647 | valid AUROC    0.866 | valid AUPRC    0.573
# ----------------------------------------------------------------------------------------------------
# | end of epoch 647 | test  AUROC    0.868 | test  AUPRC    0.582
# ----------------------------------------------------------------------------------------------------

# %%
# for epoch in range(50):
#     for expr_embedding, label_matrix, mask in interaction_train_loader:
#         expr_embedding = expr_embedding.to(device)  # [batch_size, num_genes, embedding_dim]
#         label_matrix = label_matrix.to(device)      # [batch_size, num_genes, num_genes]
#         mask = mask.to(device)                      # [batch_size, num_genes, num_genes]

#         # Forward pass
#         outputs = model(expr_embedding)  # Should output [batch_size, num_genes, num_genes]

#         # Compute the loss
#         loss_fn = torch.nn.BCEWithLogitsLoss(reduction='none')
#         loss = loss_fn(outputs, label_matrix)
#         masked_loss = loss * mask
#         final_loss = masked_loss.sum() / mask.sum()

#         # Backpropagation and optimization steps
#         optimizer.zero_grad()
#         final_loss.backward()
#         optimizer.step()
#         print(f"Epoch {epoch}, Loss: {final_loss.item()}")
